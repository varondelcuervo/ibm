# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2023-06-23 15:46:12--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: 'm4_survey_data.sqlite'
#
#      0K .......... .......... .......... .......... ..........  0%  318K 1m53s
#     50K .......... .......... .......... .......... ..........  0%  598K 86s
#    100K .......... .......... .......... .......... ..........  0%  902K 70s
#    150K .......... .......... .......... .......... ..........  0%  511K 70s
# ...

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
QUERY = """
SELECT ConvertedComp FROM master
"""

df = pd.read_sql_query(QUERY,conn)


df.plot(kind='hist', figsize=(8, 5))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
QUERY = """
SELECT Age FROM master
"""

df = pd.read_sql_query(QUERY,conn)
#import seaborn as sns
#sns.boxplot(x=df, data=df)
df.plot(kind='box',figsize=(8, 6))
# Out:
# <Axes: >

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
QUERY = """
SELECT Age, WorkWeekHrs FROM master
"""

df = pd.read_sql_query(QUERY,conn)
df.plot(kind='scatter', x='Age', y='WorkWeekHrs')
# Out:
# <Axes: xlabel='Age', ylabel='WorkWeekHrs'>

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age FROM master
"""

df = pd.read_sql_query(QUERY,conn)

ax0 = df.plot(kind='scatter',
                    x='WorkWeekHrs',
                    y='CodeRevHrs',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s='Age'
                    )

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt


QUERY = """
SELECT COUNT(Respondent), DatabaseDesireNextYear FROM DatabaseDesireNextYear GROUP BY DatabaseDesireNextYear ORDER BY COUNT(Respondent) DESC LIMIT 5
"""
df = pd.read_sql_query(QUERY, conn)
print(df)

#SELECT COUNT(Respondent), LanguageDesireNextYear FROM LanguageDesireNextYear GROUP BY LanguageDesireNextYear ORDER BY COUNT(Respondent) DESC LIMIT 5


df['COUNT(Respondent)'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            )
plt.legend(labels=df['DatabaseDesireNextYear'], loc='upper left')
# Out:
#    COUNT(Respondent) DatabaseDesireNextYear
# 0               4328             PostgreSQL
# 1               3649                MongoDB
# 2               3331                  Redis
# 3               3281                  MySQL
# 4               2856          Elasticsearch

# %%
QUERY = """
SELECT DatabaseDesireNextYear FROM DatabaseDesireNextYear Group by DatabaseDesireNextYear
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    DatabaseDesireNextYear
# 0               Cassandra
# 1               Couchbase
# 2                DynamoDB
# 3           Elasticsearch
# 4                Firebase
# 5                 MariaDB
# 6    Microsoft SQL Server
# 7                 MongoDB
# 8                   MySQL
# 9                  Oracle
# 10              Other(s):
# 11             PostgreSQL
# 12                  Redis
# 13                 SQLite

# %%
QUERY = """
SELECT DatabaseWorkedWith FROM DatabaseWorkedWith Group by DatabaseWorkedWith
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#       DatabaseWorkedWith
# 0              Cassandra
# 1              Couchbase
# 2               DynamoDB
# 3          Elasticsearch
# 4               Firebase
# 5                MariaDB
# 6   Microsoft SQL Server
# 7                MongoDB
# 8                  MySQL
# 9                 Oracle
# 10             Other(s):
# 11            PostgreSQL
# 12                 Redis
# 13                SQLite

# %%
#How many respondents indicated that they work on 'MySQL' only? 
QUERY = """
SELECT COUNT(Respondent), DatabaseWorkedWith FROM DatabaseWorkedWith WHERE DatabaseWorkedWith == 'MySQL' AND DatabaseWorkedWith <> 'Oracle' AND DatabaseWorkedWith <> 'Cassandra' AND DatabaseWorkedWith <> 'MariaDB' AND DatabaseWorkedWith <> 'Firebase' AND DatabaseWorkedWith <> 'Elasticsearch' AND DatabaseWorkedWith <> 'DynamoDB' AND DatabaseWorkedWith <> 'Couchbase'
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(Respondent) DatabaseWorkedWith
# 0               5469              MySQL

# %%
QUERY = """
SELECT LanguageDesireNextYear FROM LanguageDesireNextYear Group by LanguageDesireNextYear
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    LanguageDesireNextYear
# 0                Assembly
# 1   Bash/Shell/PowerShell
# 2                       C
# 3                      C#
# 4                     C++
# 5                 Clojure
# 6                    Dart
# 7                  Elixir
# 8                  Erlang
# 9                      F#
# 10                     Go
# 11               HTML/CSS
# 12                   Java
# 13             JavaScript
# 14                 Kotlin
# 15            Objective-C
# 16              Other(s):
# 17                    PHP
# 18                 Python
# 19                      R
# 20                   Ruby
# 21                   Rust
# 22                    SQL
# 23                  Scala
# 24                  Swift
# 25             TypeScript
# 26                    VBA
# 27            WebAssembly

# %%
#In the list of most popular languages respondents wish to learn next year, what is the rank of Python?
QUERY = """
SELECT COUNT(Respondent), LanguageDesireNextYear FROM LanguageDesireNextYear GROUP BY LanguageDesireNextYear ORDER BY COUNT(Respondent) DESC LIMIT 5
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(Respondent) LanguageDesireNextYear
# 0               6630             JavaScript
# 1               5328               HTML/CSS
# 2               5239                 Python
# 3               5012                    SQL
# 4               4088             TypeScript

# %%
QUERY = """
SELECT count(Respondent), LanguageDesireNextYear FROM LanguageDesireNextYear WHERE LanguageDesireNextYear == 'Python'
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    count(Respondent) LanguageDesireNextYear
# 0               5239                 Python

# %%
#How many respondents indicated that they currently work with 'SQL'? 
QUERY = """
SELECT count(Respondent), LanguageWorkedWith FROM LanguageWorkedWith WHERE LanguageWorkedWith == 'SQL'
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    count(Respondent) LanguageWorkedWith
# 0               7106                SQL

# %%
QUERY = """
SELECT * FROM LanguageDesireNextYear ORDER BY Respondent DESC
"""
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#        Respondent LanguageDesireNextYear
# 0           25142  Bash/Shell/PowerShell
# 1           25142                      C
# 2           25142                    C++
# 3           25142                 Python
# 4           25142                      R
# ...           ...                    ...
# 55759           9              Other(s):
# 55760           4                      C
# 55761           4                     C#
# 55762           4             JavaScript
# 55763           4                    SQL
#
# [55764 rows x 2 columns]

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here
QUERY = """
SELECT WorkWeekHrs, CodeRevHrs FROM master WHERE AGE BETWEEN 30 AND 35
"""
df = pd.read_sql_query(QUERY, conn)
df = df.groupby('CodeRevHrs')['WorkWeekHrs'].median()
df.plot(kind='area',
             stacked=True,
             figsize=(20, 10))
# Out:
# <Axes: xlabel='CodeRevHrs'>

# %%
QUERY = """
SELECT * FROM master
"""

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# 0

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
QUERY = """
SELECT ConvertedComp, Age FROM master WHERE Age BETWEEN 25 AND 30
"""

df = pd.read_sql_query(QUERY,conn)

#df.set_index('Age')
df = df.groupby(by='Age')['ConvertedComp'].median()
df.plot(kind='line')
# Out:
# <Axes: xlabel='Age'>

# %%
QUERY = """
SELECT Age, ConvertedComp
FROM master
Where Age between 45 and 60
"""

df = pd.read_sql_query(QUERY,conn)
df = df.groupby(by='Age')['ConvertedComp'].median()
df.plot()
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
QUERY = """
SELECT MainBranch, count(MainBranch) FROM master GROUP BY MainBranch
"""

df = pd.read_sql_query(QUERY,conn)

df.plot(kind='bar')
# Out:
# <Axes: >

# %%
# your code goes here
QUERY = """
SELECT COUNT(Respondent), MainBranch FROM master GROUP BY MainBranch ORDER BY COUNT(Respondent) DESC LIMIT 5
"""

df = pd.read_sql_query(QUERY,conn)

print(df)
# Out:
#    COUNT(Respondent)                                         MainBranch
# 0              10618                     I am a developer by profession
# 1                780  I am not primarily a developer, but I write co...

# %%
# your code goes here
QUERY = """
SELECT COUNT(Respondent), DevType FROM DevType GROUP BY DevType ORDER BY COUNT(Respondent) DESC LIMIT 5
"""

df = pd.read_sql_query(QUERY,conn)

print(df)
# Out:
#    COUNT(Respondent)                                        DevType
# 0               6928                          Developer, full-stack
# 1               6290                            Developer, back-end
# 2               3920                           Developer, front-end
# 3               2575  Developer, desktop or enterprise applications
# 4               1959                              Developer, mobile

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
